# %%
import html
import re
import string

import pandas as pd
from tqdm import tqdm

# # Load the data
# df = pd.read_parquet("hacker_news_ml_ready.parquet")

# Drop rows with missing or empty titles
df = df[df['title'].notnull() & (df['title'].str.strip() != '')]
print(f"Remaining rows after filtering: {len(df)}")
# Out:
# Remaining rows after filtering: 4920775

# %%
def fast_clean_and_tokenize(text):
    if not isinstance(text, str):
        return None
    text = html.unescape(text)
    text = re.sub(r"&", "and", text)
    text = re.sub(r"\(.*?\)", "", text)
    text = re.sub(r"\[.*?\]", "", text)
    text = text.replace("-", " ")  # <-- NEW: break up compound words
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\s+", " ", text)
    tokens = text.lower().strip().split()
    tokens = [t for t in tokens if t.isalnum()]
    return tokens if tokens else None

# %%
df
# Out:
#                                                      title   type  \
# 0        "What May Happen in the Next Hundred Years", f...  story
# 1             Getting Started with JavaScript Unit Testing  story
# 2        Armstrong, the Django-based and open-source ne...  story
# 3                     Why Web Reviewers Make Up Bad Things  story
# 4        You Weren't Meant to Have a Boss: The Cliff Notes  story
# ...                                                    ...    ...
# 5148742                         Northeast Blackout of 2003  story
# 5148743  PieChartMaster- Unlock your Pie/Rose chart cre...  story
# 5148744                  The Greatest Checkmate Ever Given  story
# 5148745  Scrapling: Fast, Adaptive Web Scraping for Python  story
# 5148746                       Monkeys Predict US Elections  story
#
#                       by                time  score  \
# 0            ColinWright 2011-10-24 16:27:00     19
# 1                   hncj 2012-01-23 11:39:25      1
# 2             andymboyle 2011-10-24 16:27:36      2
# 3                digisth 2013-07-16 05:16:26      1
# 4                jazzdev 2008-03-30 09:46:25      1
# ...                  ...                 ...    ...
# 5148742   sandwichsphinx 2024-10-13 23:41:46      1
# 5148743       emperinter 2024-10-13 23:42:21      1
# 5148744       mellosouls 2024-10-13 23:45:21      1
# 5148745          d4vinci 2024-10-13 23:49:42      1
# 5148746  giuliomagnifico 2024-10-13 23:53:00      1
#
#                                                        url  \
# 0        http://www.howtobearetronaut.com/wp-content/up...
# 1        http://blogs.lessthandot.com/index.php/WebDev/...
# 2        http://www.marketwatch.com/story/the-bay-citiz...
# 3        http://bits.blogs.nytimes.com/2013/07/15/why-w...
# 4                     http://paulgraham.com/bossnotes.html
# ...                                                    ...
# 5148742  https://en.wikipedia.org/wiki/Northeast_blacko...
# 5148743  https://apps.apple.com/us/app/piechartmaster-u...
# 5148744        https://www.youtube.com/watch?v=UULlFap1Zko
# 5148745               https://github.com/D4Vinci/Scrapling
# 5148746  https://www.biorxiv.org/content/10.1101/2024.0...
#
#                          domain
# 0         howtobearetronaut.com
# 1         blogs.lessthandot.com
# 2               marketwatch.com
# 3        bits.blogs.nytimes.com
# 4                paulgraham.com
# ...                         ...
# 5148742        en.wikipedia.org
# 5148743          apps.apple.com
# 5148744             youtube.com
# 5148745              github.com
# 5148746             biorxiv.org
#
# [4920775 rows x 7 columns]

# %%
from tqdm import tqdm
tqdm.pandas(desc="Tokenising titles")

df["tokens"] = df["title"].progress_apply(fast_clean_and_tokenize)

# Drop rows where tokenisation failed (too short or bad input)
df = df[df["tokens"].notnull()]
# Out:
# Tokenising titles:   0%|          | 0/4920775 [00:00<?, ?it/s]
# Tokenising titles: 100%|██████████| 4920775/4920775 [01:01<00:00, 80311.53it/s]

# %%
df['tokens'][2]
# Out:
# ['armstrong',
#  'the',
#  'django',
#  'based',
#  'and',
#  'open',
#  'source',
#  'news',
#  'cms',
#  'is',
#  'now',
#  'released']

# %%
# Out:
#                                                      title   type  \
# 0        "What May Happen in the Next Hundred Years", f...  story
# 1             Getting Started with JavaScript Unit Testing  story
# 2        Armstrong, the Django-based and open-source ne...  story
# 3                     Why Web Reviewers Make Up Bad Things  story
# 4        You Weren't Meant to Have a Boss: The Cliff Notes  story
# ...                                                    ...    ...
# 5148742                         Northeast Blackout of 2003  story
# 5148743  PieChartMaster- Unlock your Pie/Rose chart cre...  story
# 5148744                  The Greatest Checkmate Ever Given  story
# 5148745  Scrapling: Fast, Adaptive Web Scraping for Python  story
# 5148746                       Monkeys Predict US Elections  story
#
#                       by                time  score  \
# 0            ColinWright 2011-10-24 16:27:00     19
# 1                   hncj 2012-01-23 11:39:25      1
# 2             andymboyle 2011-10-24 16:27:36      2
# 3                digisth 2013-07-16 05:16:26      1
# 4                jazzdev 2008-03-30 09:46:25      1
# ...                  ...                 ...    ...
# 5148742   sandwichsphinx 2024-10-13 23:41:46      1
# 5148743       emperinter 2024-10-13 23:42:21      1
# 5148744       mellosouls 2024-10-13 23:45:21      1
# 5148745          d4vinci 2024-10-13 23:49:42      1
# 5148746  giuliomagnifico 2024-10-13 23:53:00      1
#
#                                                        url  \
# 0        http://www.howtobearetronaut.com/wp-content/up...
# 1        http://blogs.lessthandot.com/index.php/WebDev/...
# 2        http://www.marketwatch.com/story/the-bay-citiz...
# 3        http://bits.blogs.nytimes.com/2013/07/15/why-w...
# 4                     http://paulgraham.com/bossnotes.html
# ...                                                    ...
# 5148742  https://en.wikipedia.org/wiki/Northeast_blacko...
# 5148743  https://apps.apple.com/us/app/piechartmaster-u...
# 5148744        https://www.youtube.com/watch?v=UULlFap1Zko
# 5148745               https://github.com/D4Vinci/Scrapling
# 5148746  https://www.biorxiv.org/content/10.1101/2024.0...
#
#                          domain  \
# 0         howtobearetronaut.com
# 1         blogs.lessthandot.com
# 2               marketwatch.com
# 3        bits.blogs.nytimes.com
# 4                paulgraham.com
# ...                         ...
# 5148742        en.wikipedia.org
# 5148743          apps.apple.com
# 5148744             youtube.com
# 5148745              github.com
# 5148746             biorxiv.org
#
#                                                     tokens
# 0        [what, may, happen, in, the, next, hundred, ye...
# 1        [getting, started, with, javascript, unit, tes...
# 2        [armstrong, the, django, based, and, open, sou...
# 3             [why, web, reviewers, make, up, bad, things]
# 4        [you, werent, meant, to, have, a, boss, the, c...
# ...                                                    ...
# 5148742                    [northeast, blackout, of, 2003]
# 5148743  [piechartmaster, unlock, your, pierose, chart,...
# 5148744            [the, greatest, checkmate, ever, given]
# 5148745  [scrapling, fast, adaptive, web, scraping, for...
# 5148746                  [monkeys, predict, us, elections]
#
# [4919142 rows x 8 columns]

# %%
df["tokens"].explode().value_counts().head(100)  # most common tokens
# Out:
# tokens
# the          1100606
# to            923113
# a             737235
# of            660627
# in            590187
#               ...
# social         35095
# microsoft      34613
# who            34094
# could          34004
# go             33887
# Name: count, Length: 100, dtype: int64

# %%
df.to_parquet("hn_posts_tokenised.parquet", engine='pyarrow')

# %%
# Load the data
df = pd.read_parquet("hn_posts_tokenised.parquet")

# %%
import pickle

with open("user_lookup.pkl", "rb") as f:
    user_lookup = pickle.load(f)

# %%
user_lookup["pg"]
# Out:
# {'created': datetime.datetime(2006, 10, 9, 18, 21, 32),
#  'karma': 157316,
#  'submitted_count': 15565}

# %%
def get_user_features(username, post_time):
    user = user_lookup.get(username)
    if not user:
        return None, None, None
    age_at_post = (post_time - user["created"]).total_seconds()
    return user["karma"], user["submitted_count"], age_at_post

# %%
user_df = pd.DataFrame.from_dict(user_lookup, orient='index')
user_df.index.name = 'by'
user_df.reset_index(inplace=True)

# %%
# Convert 'created' to datetime if it’s not already
if not pd.api.types.is_datetime64_any_dtype(user_df['created']):
    user_df['created'] = pd.to_datetime(user_df['created'])

# Convert post times in your main df
if not pd.api.types.is_datetime64_any_dtype(df['time']):
    df['time'] = pd.to_datetime(df['time'], unit='s')

# %%
df = df.merge(user_df, on='by', how='left')

# %%
df['user_age_at_post'] = (df['time'] - df['created']).dt.total_seconds()

# %%
df
# Out:
#                                                      title   type  \
# 0        "What May Happen in the Next Hundred Years", f...  story
# 1             Getting Started with JavaScript Unit Testing  story
# 2        Armstrong, the Django-based and open-source ne...  story
# 3                     Why Web Reviewers Make Up Bad Things  story
# 4        You Weren't Meant to Have a Boss: The Cliff Notes  story
# ...                                                    ...    ...
# 4919137                         Northeast Blackout of 2003  story
# 4919138  PieChartMaster- Unlock your Pie/Rose chart cre...  story
# 4919139                  The Greatest Checkmate Ever Given  story
# 4919140  Scrapling: Fast, Adaptive Web Scraping for Python  story
# 4919141                       Monkeys Predict US Elections  story
#
#                       by                time  score  \
# 0            ColinWright 2011-10-24 16:27:00     19
# 1                   hncj 2012-01-23 11:39:25      1
# 2             andymboyle 2011-10-24 16:27:36      2
# 3                digisth 2013-07-16 05:16:26      1
# 4                jazzdev 2008-03-30 09:46:25      1
# ...                  ...                 ...    ...
# 4919137   sandwichsphinx 2024-10-13 23:41:46      1
# 4919138       emperinter 2024-10-13 23:42:21      1
# 4919139       mellosouls 2024-10-13 23:45:21      1
# 4919140          d4vinci 2024-10-13 23:49:42      1
# 4919141  giuliomagnifico 2024-10-13 23:53:00      1
#
#                                                        url  \
# 0        http://www.howtobearetronaut.com/wp-content/up...
# 1        http://blogs.lessthandot.com/index.php/WebDev/...
# 2        http://www.marketwatch.com/story/the-bay-citiz...
# 3        http://bits.blogs.nytimes.com/2013/07/15/why-w...
# 4                     http://paulgraham.com/bossnotes.html
# ...                                                    ...
# 4919137  https://en.wikipedia.org/wiki/Northeast_blacko...
# 4919138  https://apps.apple.com/us/app/piechartmaster-u...
# 4919139        https://www.youtube.com/watch?v=UULlFap1Zko
# 4919140               https://github.com/D4Vinci/Scrapling
# 4919141  https://www.biorxiv.org/content/10.1101/2024.0...
#
#                          domain  \
# 0         howtobearetronaut.com
# 1         blogs.lessthandot.com
# 2               marketwatch.com
# 3        bits.blogs.nytimes.com
# 4                paulgraham.com
# ...                         ...
# 4919137        en.wikipedia.org
# 4919138          apps.apple.com
# 4919139             youtube.com
# 4919140              github.com
# 4919141             biorxiv.org
#
#                                                     tokens  \
# 0        [what, may, happen, in, the, next, hundred, ye...
# 1        [getting, started, with, javascript, unit, tes...
# 2        [armstrong, the, django, based, and, open, sou...
# 3             [why, web, reviewers, make, up, bad, things]
# 4        [you, werent, meant, to, have, a, boss, the, c...
# ...                                                    ...
# 4919137                    [northeast, blackout, of, 2003]
# 4919138  [piechartmaster, unlock, your, pierose, chart,...
# 4919139            [the, greatest, checkmate, ever, given]
# 4919140  [scrapling, fast, adaptive, web, scraping, for...
# 4919141                  [monkeys, predict, us, elections]
#
#                     created     karma  submitted_count  user_age_at_post
# 0       2009-12-14 16:39:30  127765.0          17656.0        58664850.0
# 1       2011-10-29 16:27:52      44.0             26.0         7413093.0
# 2       2011-05-04 14:29:09     714.0             54.0        14954307.0
# 3       2011-01-06 10:45:47    2395.0            532.0        79641039.0
# 4       2007-09-26 09:28:50     543.0            242.0        16071455.0
# ...                     ...       ...              ...               ...
# 4919137 2024-07-10 22:37:37      14.0             22.0         8211849.0
# 4919138 2024-06-30 15:12:24       7.0             35.0         9102597.0
# 4919139 2019-04-12 07:34:13   14490.0           3341.0       173808668.0
# 4919140 2024-10-13 23:48:49       1.0              2.0              53.0
# 4919141 2020-06-01 07:12:23   40731.0           5318.0       137868037.0
#
# [4919142 rows x 12 columns]

# %%
df.to_parquet("hn_with_user_stats.parquet", engine='pyarrow')

# %%
feature_df = df[["time", "tokens", "domain", "user_age_at_post", "karma", "submitted_count", "score"]]

# %%
feature_df
# Out:
#                        time  \
# 0       2011-10-24 16:27:00
# 1       2012-01-23 11:39:25
# 2       2011-10-24 16:27:36
# 3       2013-07-16 05:16:26
# 4       2008-03-30 09:46:25
# ...                     ...
# 4919137 2024-10-13 23:41:46
# 4919138 2024-10-13 23:42:21
# 4919139 2024-10-13 23:45:21
# 4919140 2024-10-13 23:49:42
# 4919141 2024-10-13 23:53:00
#
#                                                     tokens  \
# 0        [what, may, happen, in, the, next, hundred, ye...
# 1        [getting, started, with, javascript, unit, tes...
# 2        [armstrong, the, django, based, and, open, sou...
# 3             [why, web, reviewers, make, up, bad, things]
# 4        [you, werent, meant, to, have, a, boss, the, c...
# ...                                                    ...
# 4919137                    [northeast, blackout, of, 2003]
# 4919138  [piechartmaster, unlock, your, pierose, chart,...
# 4919139            [the, greatest, checkmate, ever, given]
# 4919140  [scrapling, fast, adaptive, web, scraping, for...
# 4919141                  [monkeys, predict, us, elections]
#
#                          domain  user_age_at_post     karma  submitted_count  \
# 0         howtobearetronaut.com        58664850.0  127765.0          17656.0
# 1         blogs.lessthandot.com         7413093.0      44.0             26.0
# 2               marketwatch.com        14954307.0     714.0             54.0
# 3        bits.blogs.nytimes.com        79641039.0    2395.0            532.0
# 4                paulgraham.com        16071455.0     543.0            242.0
# ...                         ...               ...       ...              ...
# 4919137        en.wikipedia.org         8211849.0      14.0             22.0
# 4919138          apps.apple.com         9102597.0       7.0             35.0
# 4919139             youtube.com       173808668.0   14490.0           3341.0
# 4919140              github.com              53.0       1.0              2.0
# 4919141             biorxiv.org       137868037.0   40731.0           5318.0
#
#          score
# 0           19
# 1            1
# 2            2
# 3            1
# 4            1
# ...        ...
# 4919137      1
# 4919138      1
# 4919139      1
# 4919140      1
# 4919141      1
#
# [4919142 rows x 7 columns]

# %%
feature_df.to_parquet("feature_df.parquet", engine='pyarrow')
